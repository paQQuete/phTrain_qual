# %%
import asyncio
import ccxt.async_support as ccxt

from pprint import pprint

# %%
hitbtc   = ccxt.hitbtc({'verbose': True})

# %%
hitbtc_markets = await hitbtc.load_markets()
pprint(hitbtc.id, hitbtc_markets)
# Out:
# fetch Request: hitbtc GET https://api.hitbtc.com/api/2/public/currency RequestHeaders: {'User-Agent': 'python-requests/2.28.2', 'Accept-Encoding': 'gzip, deflate'} RequestBody: None
#
# ...
